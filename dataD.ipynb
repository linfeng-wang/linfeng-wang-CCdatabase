# %%
import pandas as pd
import icecream as ic
import numpy as np
import plotly
import matplotlib as plt
import xml.etree.ElementTree as ET
import pandas as pd
import psycopg2
import psycopg2.extras

# %%
from cmapPy.pandasGEXpress import parse
parse.parse('/Users/linfengwang/Downloads/cdrp.img.profiles_n30440x812.gctx',col_meta_only=True)
# Out:
# chd                   cell_id  mfc_plate_dim     mfc_plate_name  \
# cid
# C-2113-01-CMP-002:A01    U2OS          384.0  C-2113-01-CMP-002
# C-2113-01-CMP-002:A02    U2OS          384.0  C-2113-01-CMP-002
# C-2113-01-CMP-002:A03    U2OS          384.0  C-2113-01-CMP-002
# C-2113-01-CMP-002:A04    U2OS          384.0  C-2113-01-CMP-002
# C-2113-01-CMP-002:A05    U2OS          384.0  C-2113-01-CMP-002
# ...                       ...            ...                ...
# H-CBLP-002-4:P20         U2OS          384.0       H-CBLP-002-4
# H-CBLP-002-4:P21         U2OS          384.0       H-CBLP-002-4
# H-CBLP-002-4:P22         U2OS          384.0       H-CBLP-002-4
# H-CBLP-002-4:P23         U2OS          384.0       H-CBLP-002-4
# H-CBLP-002-4:P24         U2OS          384.0       H-CBLP-002-4
#
# chd                   mfc_plate_well      pert_desc  pert_dose pert_dose_unit  \
# cid
# C-2113-01-CMP-002:A01            A01  BRD-K89626439  20.000000             um
# ...

# %%
data_dfs

# %%
cmapPy.pandasGEXpress.gctx2gct.gctx2gct_main('/Users/linfengwang/Downloads/cdrp.img.profiles_n30440x812.gctx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 cmapPy.pandasGEXpress.gctx2gct.gctx2gct_main('/Users/linfengwang/Downloads/cdrp.img.profiles_n30440x812.gctx')
#
# AttributeError: module 'cmapPy.pandasGEXpress' has no attribute 'gctx2gct'
